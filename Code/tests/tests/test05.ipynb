# %% [markdown]
# <div style="float: left">
#   <img src='https://www.tu-clausthal.de/fileadmin/TU_Clausthal/images/CorporateDesign/Logo/Logo_TUC_de_Web.gif'>
# </div>
# <div style="float: right; font-size: 0.8em">
#   <div style="margin-bottom: 0.8em">
#     <span style="font-weight: bold; font-size: 1.2em;">Institut für Mathematik</span><br />
#   </div>
#     <div>
#         Prof. Dr. Andreas Potschka<br />
#         Kaisar Dawara
#     </div>
#   </div>
# </div>

# %% [markdown]
# # TUC Drillbotics Trajectory Optimization Tool
#
# ## Abstract
#
# The TUC Drillbotics team participates in the international Drillbotics competition, where the drilling trajectory must be planned through a set of goal points that are not aligned in a straight line. The planned trajectory will be executed by an autonomous miniature drilling rig. Constraints on the trajectory are imposed by the physical properties of the Bottom Hole Assembly (BHA).
#
# ---
#
# ## Introduction
#
# In the context of the Drillbotics competition, a key challenge lies in the automated generation of drillable trajectories through a predefined set of 3D coordinates, all under mechanical and physical constraints. To facilitate the development and comparison of various trajectory planning algorithms, a systematic evaluation framework is required.
#
# The goal of this project is to design and implement a **trajectory optimization and evaluation tool** that quantitatively assesses the output of different planning approaches.
#
# ---
#
# ## Task Description
#
# The task is to program a tool that evaluates generated trajectories. The tool should accept either a **discrete** (sequence of waypoints) or **continuous** (parametric curve) representation of a trajectory and compute a **composite cost function** based on multiple, weighted evaluation criteria.
#
# ### Evaluation Criteria
#
# The evaluation tool will compute a cost based on the following (customizable) metrics:
#
# * **Total Path Length**
#     Affects drilling time and material wear.
#
# * **Cumulative Angular Deviation / Curvature**
#     Penalizes sharp bends and infeasible transitions. Encourages smoother trajectories and discourages zigzag paths, even if each individual bend is mechanically feasible.
#
# * **Mechanical Feasibility Constraints**
#     Includes constraints such as maximum allowable deviation per segment and minimum radius of curvature.
#
# * **Estimated Energy Consumption and Time**
#     Based on the geometry of the path and expected drilling dynamics.
#
# ### Features
#
# * Composite cost function for multi-objective evaluation.
# * Support for sensitivity analysis (adjustable weights).
# * Comparison and ranking of different trajectory planning algorithms.
# * Modular design to allow future extensions.
#
# ### Purpose
#
# The scalar cost produced by the tool provides a **quantitative and objective basis** for:
#
# * Comparing and ranking trajectory planning algorithms.
# * Supporting iterative algorithm optimization.
# * Encouraging multi-objective optimization in planning strategies.
# ---

# %%
# importaions
from rockit import *
import casadi as ca
import numpy as np
import matplotlib.pyplot as plt

# %%
def create_stage(ocp, FreeTime=10):
    stage = ocp.stage(T=FreeTime(FreeTime))

    # states
    x_pos = stage.state()
    y_pos = stage.state()
    z_pos = stage.state()
    t = stage.state()
    azimuth = stage.state()
    inclination = stage.state()

    # controls
    u_azimuth_rate_ds = stage.control()     # Represents u_1 = d(azimuth)/ds
    u_inclination_rate_ds = stage.control() # Represents u_2 = d(inclination)/ds
    inverse_rop = stage.control() 

    # The geometric part of the dynamics (speed has been factored out)
    v_x_ds = ca.sin(inclination) * ca.cos(azimuth)
    v_y_ds = ca.sin(inclination) * ca.sin(azimuth)
    v_z_ds = ca.cos(inclination)

    # Set the new derivatives with respect to 's'
    stage.set_der(x_pos, v_x_ds)
    stage.set_der(y_pos, v_y_ds)
    stage.set_der(z_pos, v_z_ds)
    stage.set_der(azimuth, u_azimuth_rate_ds)
    stage.set_der(inclination, u_inclination_rate_ds)

    # dt/ds = 1 / speed = inverse_rop
    stage.set_der(t, inverse_rop)

    # Define the Cost Function / goal
    stage.add_objective(stage.integral(inverse_rop))


    stage.subject_to(stage.at_t0(x_pos) == 0)
    stage.subject_to(stage.at_t0(y_pos) == 0)
    stage.subject_to(stage.at_t0(z_pos) == 0)
    stage.subject_to(stage.at_t0(azimuth) == 0)
    # Force the drill to always point downwards at the start 
    stage.subject_to(stage.at_t0(inclination) == ca.pi)
    stage.subject_to(stage.at_t0(t) == 0)

    # --- Final Conditions ---
    goal_point = [5, 5, -30]
    stage.subject_to(stage.at_tf(x_pos) == goal_point[0])
    stage.subject_to(stage.at_tf(y_pos) == goal_point[1])
    stage.subject_to(stage.at_tf(z_pos) == goal_point[2])
    # ocp.subject_to(ocp.at_tf(u_azimuth_rate_ds) == 0)
    # ocp.subject_to(ocp.at_tf(u_inclination_rate_ds) == 0)

    # --- Path Constraints (Control Limits) ---

    max_bur = 0.05 # max build-up rate in rad/m
    stage.subject_to(u_inclination_rate_ds >= -max_bur)
    stage.subject_to(u_inclination_rate_ds <=  max_bur)
    # -> In order to prevent the trajectory from going upwards and to force it to point downwards(iclination between 90 and 270 degrees):
    # -> x_z = cos(I) for x_z < 0 => I in {pi/2, 3*pi/2}
    stage.subject_to(inclination >= ca.pi/2)
    stage.subject_to(inclination <= 3*ca.pi/2)

    stage.subject_to(u_azimuth_rate_ds >= -max_bur)
    stage.subject_to(u_azimuth_rate_ds <=  max_bur)

    rop_max = 30 # max speed in m/min
    rop_min = 5  # min speed (must be > 0)

    # If rop_min <= ROP <= rop_max, then 1/rop_max <= 1/ROP <= 1/rop_min
    stage.subject_to(inverse_rop >= 1/rop_max)
    stage.subject_to(inverse_rop <= 1/rop_min)

# %%
# Creating an Optimal Control Problem
ocp = Ocp() # Guess for total arc length
stage = ocp.stage(T=FreeTime(10))
stage.method(DirectCollocation(N=10))

# %%
# The state now has 6 dimensions: [x_pos, y_pos, z_pos, azimuth, inclination]
x_pos = stage.state()
y_pos = stage.state()
z_pos = stage.state()
t = stage.state()
azimuth = stage.state()
inclination = stage.state()

# %%
# Controls are now derivatives with respect to arc length 's'
u_azimuth_rate_ds = stage.control()     # Represents u_1 = d(azimuth)/ds
u_inclination_rate_ds = stage.control() # Represents u_2 = d(inclination)/ds
inverse_rop = stage.control()           # Represents u_3 = 1/ROP = 1/speed
# inverse_rop1 = ocp.variable()

# %%
# Other Aproach to optimize the correct T for the solver
# T = ocp.variable() 
# L = sqrt(x_pos**2+y_pos**2+z_pos**2) # Straight line (fastes undrillable way)
# T_min = L/v # Straight-line time
# ocp.subject_to(T >= T_min) 
# ocp.set_initial(T, 1.2 * k_min) # init value with margin to avoid feasbility 

# v_x = v * ca.sin(inclination) * ca.cos(azimuth)
# v_y = v * ca.sin(inclination)* ca.sin(azimuth)
# v_z = v * ca.cos(inclination)

# The geometric part of the dynamics (speed has been factored out)
v_x_ds = ca.sin(inclination) * ca.cos(azimuth)
v_y_ds = ca.sin(inclination) * ca.sin(azimuth)
v_z_ds = ca.cos(inclination)

# Set the new derivatives with respect to 's'
stage.set_der(x_pos, v_x_ds)
stage.set_der(y_pos, v_y_ds)
stage.set_der(z_pos, v_z_ds)
stage.set_der(azimuth, u_azimuth_rate_ds)
stage.set_der(inclination, u_inclination_rate_ds)

# dt/ds = 1 / speed = inverse_rop
stage.set_der(t, inverse_rop)

# %%
# Define the Cost Function / goal

stage.add_objective(stage.integral(inverse_rop))

# %%
# ======> Constraints / rules

# --- Initial Conditions ---
# Start at origin (0,0,0), pointing straight down.
# Azimuth pointing straight down '0'.
# Inclination is pi (180 degrees) for pointing down.

stage.subject_to(stage.at_t0(x_pos) == 0)
stage.subject_to(stage.at_t0(y_pos) == 0)
stage.subject_to(stage.at_t0(z_pos) == 0)
stage.subject_to(stage.at_t0(azimuth) == 0)
# Force the drill to always point downwards at the start 
stage.subject_to(stage.at_t0(inclination) == ca.pi)
stage.subject_to(stage.at_t0(t) == 0)

# --- Final Conditions ---
goal_point = [5, 5, -30]
stage.subject_to(stage.at_tf(x_pos) == goal_point[0])
stage.subject_to(stage.at_tf(y_pos) == goal_point[1])
stage.subject_to(stage.at_tf(z_pos) == goal_point[2])
# ocp.subject_to(ocp.at_tf(u_azimuth_rate_ds) == 0)
# ocp.subject_to(ocp.at_tf(u_inclination_rate_ds) == 0)

# --- Path Constraints (Control Limits) ---

max_bur = 0.05 # max build-up rate in rad/m
stage.subject_to(u_inclination_rate_ds >= -max_bur)
stage.subject_to(u_inclination_rate_ds <=  max_bur)
# -> In order to prevent the trajectory from going upwards and to force it to point downwards(iclination between 90 and 270 degrees):
# -> x_z = cos(I) for x_z < 0 => I in {pi/2, 3*pi/2}
stage.subject_to(inclination >= ca.pi/2)
stage.subject_to(inclination <= 3*ca.pi/2)

stage.subject_to(u_azimuth_rate_ds >= -max_bur)
stage.subject_to(u_azimuth_rate_ds <=  max_bur)

rop_max = 30 # max speed in m/min
rop_min = 5  # min speed (must be > 0)

# If rop_min <= ROP <= rop_max, then 1/rop_max <= 1/ROP <= 1/rop_min
stage.subject_to(inverse_rop >= 1/rop_max)
stage.subject_to(inverse_rop <= 1/rop_min)

# %%
# Solve the OCP

ocp.solver('ipopt')
sol = ocp.solve()
# Out:
# This is Ipopt version 3.14.11, running with linear solver MUMPS 5.4.1.
#
# Number of nonzeros in equality constraint Jacobian...:     2129
# Number of nonzeros in inequality constraint Jacobian.:       89
# Number of nonzeros in Lagrangian Hessian.............:      431
#
# Total number of variables............................:      337
#                      variables with only lower bounds:        0
#                 variables with lower and upper bounds:        0
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:      309
# Total number of inequality constraints...............:       89
#         inequality constraints with only lower bounds:       45
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:       44
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  0.0000000e+00 3.00e+01 1.00e+00  -1.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.3633764e-02 2.97e+01 5.10e+04  -1.0 2.74e+01    -  1.06e-02 1.10e-02h  1
#    2r 1.3633764e-02 2.97e+01 9.99e+02   1.5 0.00e+00   6.0 0.00e+00 1.67e-07R  2
#    3r 2.4376938e-01 2.99e+01 9.94e+02   1.5 5.66e+01    -  9.39e-02 4.87e-03f  1
#    4r 3.2906569e-03 3.06e+01 8.09e+04   0.8 4.01e+02    -  5.32e-02 2.40e-02f  1
#    5r 7.4731531e-03 3.07e+01 7.42e+04   0.8 8.22e+00   2.0 1.89e-01 1.29e-01f  1
#    6r 1.4398222e-02 3.10e+01 7.19e+04   0.8 1.25e+01   1.5 3.02e-02 5.40e-02f  1
#    7r 5.1741900e-02 3.17e+01 6.68e+04   0.8 7.81e+00   1.9 4.12e-02 2.06e-01f  1
#    8r 6.1107679e-02 3.18e+01 6.49e+04   0.8 5.26e+00   2.4 4.64e-02 3.38e-02h  1
#    9r 6.5147762e-02 3.18e+01 6.46e+04   0.8 2.10e+01   1.9 6.61e-03 4.88e-03h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10r 6.9519137e-02 3.18e+01 6.39e+04   0.8 7.56e+00   2.3 2.13e-02 1.12e-02h  1
#   11r 9.8127109e-02 3.20e+01 5.78e+04   0.8 3.18e+00   2.7 5.72e-02 1.36e-01h  1
#   12r 1.0068151e-01 3.20e+01 5.76e+04   0.8 2.12e+01   2.3 7.41e-03 2.76e-03h  1
#   13r 1.3895021e-01 3.22e+01 5.13e+04   0.8 4.66e+00   2.7 5.50e-02 1.63e-01h  1
#   14r 1.8074392e-01 3.23e+01 4.04e+04   0.8 3.25e+00   3.1 1.50e-01 3.04e-01h  1
#   15r 1.8934034e-01 3.24e+01 3.85e+04   0.8 9.60e+00   2.6 5.39e-02 4.88e-02h  1
#   16r 2.1454262e-01 3.24e+01 2.65e+04   0.8 5.06e+00   3.1 7.64e-02 5.14e-01h  1
#   17r 2.1375213e-01 3.25e+01 2.64e+04   0.8 6.44e+01   2.6 6.47e-03 1.27e-03h  1
#   18r 2.1497758e-01 3.25e+01 2.32e+04   0.8 7.67e+00   3.0 6.22e-02 1.11e-01h  1
#   19r 2.2926725e-01 3.24e+01 1.71e+04   0.8 5.70e+00   3.4 1.66e-01 2.12e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20r 2.1262458e-01 3.24e+01 1.46e+04   0.8 6.98e+00   3.0 1.60e-01 1.24e-01f  1
#   21r 2.0370697e-01 3.24e+01 1.46e+04   0.8 9.28e+01   2.5 3.38e-03 1.32e-03h  1
#   22r 1.8765856e-01 3.24e+01 1.35e+04   0.8 6.96e+00   2.9 1.90e-01 5.26e-02f  1
#   23r 1.8851682e-01 3.23e+01 1.29e+04   0.8 5.04e+00   3.3 4.32e-01 2.57e-02f  1
#   24r 1.3198784e-01 3.23e+01 1.11e+04   0.8 6.74e+00   2.9 6.49e-02 1.19e-01f  1
#   25r 1.3575802e-01 3.23e+01 9.90e+03   0.8 4.53e+00   3.3 6.48e-02 6.24e-02f  1
#   26r 9.3630926e-02 3.22e+01 8.58e+03   0.8 5.22e+00   2.8 6.44e-02 1.08e-01f  1
#   27r 1.0630510e-01 3.22e+01 7.37e+03   0.8 3.55e+00   3.2 2.27e-02 8.94e-02f  1
#   28r 1.0006799e-01 3.21e+01 6.72e+03   0.8 2.91e+00   2.8 4.22e-01 7.48e-02f  1
#   29r 1.7954237e-01 3.20e+01 4.30e+03   0.8 2.56e+00   3.2 7.84e-02 2.83e-01f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30r 1.9130593e-01 3.19e+01 4.18e+03   0.8 2.50e+00   2.7 2.49e-01 2.90e-02f  1
#   31r 2.9951437e-01 3.17e+01 3.76e+03   0.8 5.40e+00   2.2 2.56e-01 1.23e-01f  1
#   32r 3.3486341e-01 3.16e+01 3.46e+03   0.8 1.75e+00   2.7 7.07e-01 9.24e-02f  1
#   33r 4.3761473e-01 3.13e+01 3.00e+03   0.8 5.51e+00   2.2 2.90e-01 1.60e-01f  1
#   34r 4.6609657e-01 3.11e+01 2.94e+03   0.8 2.27e+01   1.7 4.92e-02 3.17e-02f  1
#   35r 5.0816274e-01 3.08e+01 2.67e+03   0.8 6.07e+00   2.1 3.18e-01 1.20e-01f  1
#   36r 5.3019682e-01 3.07e+01 2.56e+03   0.8 1.52e+01   1.7 1.53e-01 5.04e-02f  1
#   37r 5.8177777e-01 3.06e+01 2.54e+03   0.8 6.29e+01   1.2 1.06e-02 1.75e-02f  1
#   38r 6.0660141e-01 3.04e+01 2.34e+03   0.8 6.41e+00   1.6 2.25e-01 8.65e-02f  1
#   39r 6.3185479e-01 3.03e+01 2.21e+03   0.8 1.55e+01   1.1 4.12e-02 5.52e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40r 6.4083588e-01 3.02e+01 2.08e+03   0.8 4.38e+00   1.6 6.14e-01 6.36e-02f  1
#   41r 6.6828267e-01 2.98e+01 1.37e+03   0.8 1.01e+00   2.0 6.70e-01 3.48e-01f  1
#   42r 6.6927999e-01 2.94e+01 1.08e+03   0.8 2.34e+00   1.5 2.77e-01 2.09e-01f  1
#   43r 6.7813065e-01 2.91e+01 6.62e+02   0.8 8.98e-01   1.9 1.00e+00 3.91e-01f  1
#   44r 6.7797035e-01 2.85e+01 4.58e+02   0.8 1.92e+00   1.5 3.66e-01 3.09e-01f  1
#   45r 6.8756878e-01 2.79e+01 1.31e+02   0.8 7.94e-01   1.9 1.00e+00 6.99e-01f  1
#   46r 6.8350985e-01 2.77e+01 1.11e+02   0.1 1.84e+00   1.4 2.51e-01 1.52e-01f  1
#   47r 6.8396428e-01 2.74e+01 2.32e+02   0.1 8.08e-01   1.8 9.82e-01 3.72e-01f  1
#   48r 6.9012547e-01 2.67e+01 2.00e+02   0.1 2.27e+00   1.4 4.21e-01 2.92e-01f  1
#   49  7.1942292e-01 2.59e+01 4.65e+00  -1.0 2.67e+01    -  9.50e-03 3.23e-02h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  7.3625398e-01 2.54e+01 4.52e+00  -1.0 2.59e+01    -  3.83e-02 1.63e-02h  1
#   51  7.4938595e-01 2.51e+01 4.04e+01  -1.0 2.55e+01    -  5.43e-02 1.24e-02h  1
#   52  7.7128076e-01 2.46e+01 3.62e+01  -1.0 2.51e+01    -  1.97e-02 2.11e-02h  1
#   53  7.8559689e-01 2.43e+01 9.40e+01  -1.0 2.46e+01    -  2.52e-02 1.29e-02h  1
#   54  7.9292050e-01 2.41e+01 7.38e+02  -1.0 2.44e+01    -  3.65e-02 6.33e-03h  1
#   55  7.9638513e-01 2.40e+01 1.36e+03  -1.0 2.60e+01    -  5.33e-03 2.93e-03h  1
#   56  7.9755875e-01 2.40e+01 5.65e+04  -1.0 2.57e+01    -  2.53e-02 9.79e-04h  1
#   57  7.9759850e-01 2.40e+01 2.20e+08  -1.0 2.40e+01    -  1.26e-01 3.36e-05h  1
#   58r 7.9759850e-01 2.40e+01 1.00e+03   1.4 0.00e+00    -  0.00e+00 2.57e-07R  2
#   59r 8.4116671e-01 1.90e+01 9.87e+02   1.4 1.66e+02    -  1.50e-01 3.00e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60r 1.1666697e+00 3.91e+00 8.79e+02   0.7 1.45e+02    -  1.74e-01 1.04e-01f  1
#   61r 1.2874568e+00 4.54e-01 8.36e+02   0.7 2.29e+02    -  8.03e-02 1.83e-02f  1
#   62  1.5067081e+00 4.01e-01 6.90e+00  -1.0 6.08e+00    -  2.18e-02 1.19e-01f  1
#   63  1.7985650e+00 3.03e-01 5.52e+00  -1.0 4.82e+00    -  5.32e-01 3.14e-01f  1
#   64  1.8019233e+00 2.89e-01 4.77e+00  -1.0 2.15e+00    -  8.57e-02 3.69e-01f  1
#   65  1.8259420e+00 2.56e-01 1.76e+05  -1.0 1.65e+00   5.5 6.21e-03 1.16e-01h  1
#   66  1.8262080e+00 2.56e-01 1.76e+05  -1.0 1.55e+00   5.9 1.48e-01 1.46e-03h  1
#   67  1.8262267e+00 2.56e-01 1.54e+06  -1.0 1.67e+00   5.5 2.65e-01 1.03e-04h  1
#   68  1.8425050e+00 2.31e-01 5.75e+06  -1.0 1.55e+00   5.9 3.34e-01 8.92e-02h  1
#   69  1.8426519e+00 2.31e-01 3.33e+07  -1.0 1.38e+00   6.3 6.60e-01 8.82e-04h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  1.8441602e+00 2.29e-01 2.96e+07  -1.0 1.80e+00   5.8 1.89e-01 9.08e-03h  1
#   71  1.8443202e+00 2.29e-01 3.10e+07  -1.0 1.49e+00   6.3 1.32e-01 9.71e-04h  1
#   72  1.8477759e+00 2.24e-01 2.86e+07  -1.0 2.00e+00   5.8 1.14e-01 2.10e-02h  1
#   73  1.8529832e+00 2.17e-01 3.41e+07  -1.0 1.44e+00   6.2 1.00e+00 3.22e-02h  1
#   74  1.8530322e+00 2.16e-01 3.09e+07  -1.0 1.94e+00   5.7 1.28e-01 3.13e-04h  1
#   75  1.8575468e+00 2.10e-01 2.97e+07  -1.0 1.56e+00   6.2 2.15e-01 2.89e-02h  1
#   76  1.8597186e+00 2.07e-01 2.48e+07  -1.0 1.68e+00   5.7 3.02e-01 1.43e-02h  1
#   77  1.8608033e+00 2.05e-01 3.44e+07  -1.0 1.43e+00   6.1 3.16e-01 7.22e-03h  1
#   78  1.8631893e+00 2.02e-01 3.36e+07  -1.0 1.67e+00   5.6 9.70e-02 1.60e-02h  1
#   79  1.8645246e+00 2.00e-01 3.36e+07  -1.0 3.62e+00   5.2 6.27e-04 8.90e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  1.8646467e+00 2.00e-01 3.35e+07  -1.0 1.38e+00   6.5 4.52e-04 8.37e-04h  1
#   81  1.8647738e+00 2.00e-01 3.99e+07  -1.0 1.63e+00   6.0 1.51e-01 8.72e-04h  1
#   82  1.8698461e+00 1.93e-01 3.38e+07  -1.0 1.38e+00   6.4 2.21e-03 3.48e-02h  1
#   83  1.8719173e+00 1.90e-01 5.13e+07  -1.0 1.38e+00   6.9 5.87e-02 1.47e-02h  1
#   84  1.8745235e+00 1.86e-01 4.91e+07  -1.0 1.91e+00   6.4 9.27e-03 1.87e-02h  1
#   85  1.8883939e+00 1.66e-01 1.13e+07  -1.0 1.33e+00   6.8 1.85e-03 1.01e-01h  1
#   86  1.8885370e+00 1.66e-01 1.36e+07  -1.0 1.26e+00   7.2 4.58e-03 1.16e-03h  1
#   87r 1.8885370e+00 1.66e-01 1.00e+03  -0.8 0.00e+00   6.8 0.00e+00 3.91e-07R  5
#   88r 1.9032083e+00 1.51e-01 1.01e+03  -0.8 4.15e+02    -  2.52e-03 1.17e-03f  1
#   89r 1.9160150e+00 1.28e-01 1.01e+03  -0.8 1.25e+02    -  3.21e-03 2.24e-03f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  1.9130325e+00 1.27e-01 3.76e+00  -1.0 1.14e+01    -  2.45e-02 1.60e-02f  1
#   91  1.9109317e+00 1.23e-01 3.68e+00  -1.0 2.56e+01    -  2.30e-02 2.31e-02f  1
#   92  1.8768693e+00 8.76e-02 2.12e+00  -1.0 8.35e+00    -  2.09e-01 2.83e-01f  1
#   93  1.8473042e+00 7.17e-02 1.85e+00  -1.0 1.36e+00    -  5.29e-01 7.50e-01f  1
#   94  1.9161770e+00 2.84e-02 4.35e-02  -1.0 9.07e-01    -  9.83e-01 1.00e+00f  1
#   95  1.2735077e+00 2.82e-04 1.05e+00  -2.5 6.39e-01    -  8.53e-01 1.00e+00h  1
#   96  1.0759605e+00 9.02e-04 6.52e-04  -2.5 2.58e-01    -  1.00e+00 1.00e+00f  1
#   97  1.0362878e+00 8.09e-03 8.68e-02  -3.8 8.13e-01    -  6.05e-01 1.00e+00h  1
#   98  1.0350269e+00 3.09e-03 1.81e-04  -3.8 4.26e-01    -  1.00e+00 1.00e+00h  1
#   99  1.0346156e+00 7.86e-04 6.64e-05  -3.8 2.47e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  1.0325439e+00 3.25e-04 5.99e-03  -5.7 1.53e-01    -  7.82e-01 1.00e+00h  1
#  101  1.0323700e+00 2.94e-04 1.86e-03  -5.7 5.20e-02    -  8.06e-01 1.00e+00h  1
#  102  1.0323349e+00 6.96e-05 3.06e-06  -5.7 2.25e-02    -  1.00e+00 1.00e+00h  1
#  103  1.0323301e+00 1.10e-05 4.72e-07  -5.7 8.93e-03    -  1.00e+00 1.00e+00h  1
#  104  1.0322961e+00 1.25e-05 6.66e-05  -8.6 9.40e-03    -  9.09e-01 1.00e+00h  1
#  105  1.0322957e+00 1.98e-06 6.72e-08  -8.6 3.85e-03    -  1.00e+00 1.00e+00h  1
#  106  1.0322957e+00 1.53e-07 5.17e-09  -8.6 1.07e-03    -  1.00e+00 1.00e+00h  1
#  107  1.0322957e+00 9.44e-10 3.20e-11  -8.6 8.43e-05    -  1.00e+00 1.00e+00h  1
#
# Number of Iterations....: 107
#
#                                    (scaled)                 (unscaled)
# Objective...............:   1.0322956790259015e+00    1.0322956790259015e+00
# Dual infeasibility......:   3.2004856465133434e-11    3.2004856465133434e-11
# Constraint violation....:   9.4414454032687445e-10    9.4414454032687445e-10
# Variable bound violation:   0.0000000000000000e+00    0.0000000000000000e+00
# Complementarity.........:   2.5522715952827565e-09    2.5522715952827565e-09
# Overall NLP error.......:   2.5522715952827565e-09    2.5522715952827565e-09
#
#
# Number of objective function evaluations             = 117
# Number of objective gradient evaluations             = 60
# Number of equality constraint evaluations            = 117
# Number of inequality constraint evaluations          = 117
# Number of equality constraint Jacobian evaluations   = 111
# Number of inequality constraint Jacobian evaluations = 111
# Number of Lagrangian Hessian evaluations             = 107
# Total seconds in IPOPT                               = 0.553
#
# EXIT: Optimal Solution Found.
#       solver  :   t_proc      (avg)   t_wall      (avg)    n_eval
#        nlp_f  |   6.00ms ( 51.28us)   6.21ms ( 53.12us)       117
#        nlp_g  |  16.00ms (136.75us)  12.57ms (107.48us)       117
#   nlp_grad_f  |   8.00ms (131.15us)   8.87ms (145.36us)        61
#   nlp_hess_l  | 101.00ms (971.15us) 103.19ms (992.20us)       104
#    nlp_jac_g  |  68.00ms (607.14us)  66.39ms (592.79us)       112
#        total  | 553.00ms (553.00ms) 553.45ms (553.45ms)         1

# %%
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(15, 12))
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3d = fig.add_subplot(2, 1, 2, projection='3d') # This subplot is for the 3D trajectory

# --- PLOT 1: Position vs. Time ---
ts, xs = sol(stage).sample(x_pos, grid='integrator')
ax1.plot(ts, xs, label='x')
ts, ys = sol(stage).sample(y_pos, grid='integrator')
ax1.plot(ts, ys, label='y')
ts, zs = sol(stage).sample(z_pos, grid='integrator')
ax1.plot(ts, zs, label='z')
ts, xxs = sol(stage).sample(x_pos, grid='control')
ax1.set_title("Position Components vs. Time")
ax1.set_xlabel("Time (s)")
ax1.set_ylabel("Position (m)")
ax1.legend()
ax1.grid(True)


# --- PLOT 2: Control Inputs vs. Time ---
ts, vs = sol(stage).sample(inverse_rop, grid='control')
ax2.plot(ts, vs, label='Rate of Penetration')
ts, azimuth_s = sol(stage).sample(u_azimuth_rate_ds, grid='control')
ax2.plot(ts, azimuth_s, label='Change of Azimuth')
ts, inclination_s = sol(stage).sample(u_inclination_rate_ds, grid='control')
ax2.plot(ts, inclination_s, label='Change of Inclination')
ax2.set_title("Control Inputs vs. Time")
ax2.set_xlabel("Time (s)")
ax2.set_ylabel("Control Value")
ax2.legend()
ax2.grid(True)


# --- PLOT 3: The 3D Trajectory ---
# The variables xs, ys, zs were already sampled for the first plot.
ax3d.plot(xs, ys, zs, label='Optimal Trajectory', linewidth=2, color='orange')
ax3d.scatter([0], [0], [0], c='green', s=100, label='Start Point (0,0,0)')
ax3d.scatter([goal_point[0]], [goal_point[1]], [goal_point[2]], c='blue', s=100, label=f'Goal Point {goal_point}')

# Set Labels, Title, and Legend
ax3d.set_xlabel("X Position (m)")
ax3d.set_ylabel("Y Position (m)")
ax3d.set_zlabel("Z Position (Depth, m)")
ax3d.set_title("Optimized Drilling Trajectory")
ax3d.legend()

# Set Axis Limits and Direction
ax3d.set_xlim(0, 20)
ax3d.set_ylim(0, 20)
# ax3d.invert_zaxis()
ax3d.invert_yaxis()
ax3d.invert_xaxis()

# Control the Viewing Angle
ax3d.view_init(elev=30, azim=120)


# --- Display EVERYTHING at Once ---
plt.tight_layout()
plt.show()
